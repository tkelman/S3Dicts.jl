# %%
using AWS
using AWS.S3
awsEnv = AWS.AWSEnv()
# Out:
# INFO: Recompiling stale cache file /Users/jpwu/.julia/lib/v0.5/AWS.ji for module AWS.
# WARNING: Base.OS_NAME is deprecated.
#   likely near /Users/jpwu/.julia/v0.5/AWS/src/AWS.jl:31
# WARNING: Base.ASCIIString is deprecated, use String instead.
#   likely near /Users/jpwu/.julia/v0.5/AWS/src/AWS.jl:76
# WARNING: Base.ASCIIString is deprecated, use String instead.
#   likely near /Users/jpwu/.julia/v0.5/AWS/src/AWS.jl:76
# WARNING: Base.ASCIIString is deprecated, use String instead.
#   likely near /Users/jpwu/.julia/v0.5/AWS/src/AWS.jl:76
# WARNING: Base.ASCIIString is deprecated, use String instead.
#   likely near /Users/jpwu/.julia/v0.5/AWS/src/AWS.jl:76
# WARNING: `@unix_only` is deprecated, use `@static if is_unix()` instead
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in @unix_only(::Any) at ./deprecated.jl:492
#  in include_from_node1(::String) at ./loading.jl:488
# ...

# %%
f = open("/Users/jpwu//Downloads/nov.pdf")
a = string(read(f))
AWS.S3.put_object(awsEnv, "seunglab", "jpwu/test.arr", a)
# Out:
# WARNING: bytestring(v::Vector{UInt8}) is deprecated, use String(copy(v)) instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in bytestring(::Array{UInt8,1}) at ./deprecated.jl:50
#  in #do_request#33(::Bool, ::Function, ::AWS.AWSEnv, ::AWS.S3.RO) at /Users/jpwu/.julia/v0.5/AWS/src/S3.jl:682
#  in #put_object#30(::String, ::AWS.S3.PutObjectOptions, ::String, ::Function, ::AWS.AWSEnv, ::String, ::String, ::String) at /Users/jpwu/.julia/v0.5/AWS/src/S3.jl:549
#  in put_object(::AWS.AWSEnv, ::String, ::String, ::String) at /Users/jpwu/.julia/v0.5/AWS/src/S3.jl:530
#  in include_string(::String, ::String) at ./loading.jl:441
#  in execute_request(::ZMQ.Socket, ::IJulia.Msg) at /Users/jpwu/.julia/v0.5/IJulia/src/execute_request.jl:169
#  in eventloop(::ZMQ.Socket) at /Users/jpwu/.julia/v0.5/IJulia/src/eventloop.jl:8
#  in (::IJulia.##9#15)() at ./task.jl:360
# while loading In[2], in expression starting on line 3
# S3Response
# content_length: 0
# ...

# %%
using AWS.Crypto
# Crypto.md5(rand(3,3))
?Crypto.md5
# Out:
# LoadError: UndefVarError: ? not defined
# while loading In[7], in expression starting on line 3
